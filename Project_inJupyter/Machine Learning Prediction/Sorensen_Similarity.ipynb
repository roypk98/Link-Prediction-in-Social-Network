# %%
#imp libraries
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
# function for neural network
def neural_network(feat):
    
    X=feat.drop(['Link', 'C_Neighbour', 'P_Attachment',
       'Jaccard_Index', 'Adamic_Adar', 'R_Allocation', 'Salton_Cosine',
        'Promoted_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    neural=MLPClassifier()
    neural.fit(X_train,y_train)
    predictions=neural.predict(X_test)
    
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#function for knearest_neighbor
def knearest_neighbour(feat_temp):
    
    scaler=StandardScaler()
    scaler.fit(feat_temp.drop('Link',axis=1))
    scaled_feat=scaler.transform(feat_temp.drop('Link',axis=1))
    
    feat=pd.DataFrame(scaled_feat,columns=feat_temp.columns.drop('Link'))
    
    X=feat.drop(['C_Neighbour', 'P_Attachment', 'Jaccard_Index', 'Adamic_Adar', 'R_Allocation', 'Salton_Cosine',
       'Promoted_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat_temp['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    knn=KNeighborsClassifier(n_neighbors=6)
    knn.fit(X_train,y_train)
    predictions=knn.predict(X_test)
        
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#function for random_forest
def random_forest(feat):
    
    X=feat.drop(['Link', 'C_Neighbour', 'P_Attachment',
       'Jaccard_Index', 'Adamic_Adar', 'R_Allocation', 'Salton_Cosine', 'Promoted_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    rfc=RandomForestClassifier()
    rfc.fit(X_train,y_train)
    predictions=rfc.predict(X_test)
    
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#applying neural network for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        neural_network(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        neural_network(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        neural_network(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        neural_network(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        neural_network(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13478   507]
#  [  671   847]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96     13985
#            1       0.63      0.56      0.59      1518
#
#     accuracy                           0.92     15503
#    macro avg       0.79      0.76      0.77     15503
# weighted avg       0.92      0.92      0.92     15503
#
# ROC_AUC_Score 0.7608589430704741
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4493   10]
#  [ 379   70]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      4503
#            1       0.88      0.16      0.26       449
#
#     accuracy                           0.92      4952
#    macro avg       0.90      0.58      0.61      4952
# weighted avg       0.92      0.92      0.90      4952
#
# ROC_AUC_Score 0.5768406313633029
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7974   46]
#  [ 665  148]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96      8020
#            1       0.76      0.18      0.29       813
#
#     accuracy                           0.92      8833
#    macro avg       0.84      0.59      0.63      8833
# weighted avg       0.91      0.92      0.90      8833
#
# ROC_AUC_Score 0.588153079785162
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3972   33]
#  [ 180  198]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      4005
#            1       0.86      0.52      0.65       378
#
#     accuracy                           0.95      4383
#    macro avg       0.91      0.76      0.81      4383
# weighted avg       0.95      0.95      0.95      4383
#
# ROC_AUC_Score 0.757784911717496
# Vote_Prediction
#
# Confusion Matrix
#
# [[3673   44]
#  [ 366  282]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      3717
#            1       0.87      0.44      0.58       648
#
#     accuracy                           0.91      4365
#    macro avg       0.89      0.71      0.76      4365
# weighted avg       0.90      0.91      0.89      4365
#
# ROC_AUC_Score 0.7116738409111291

# %%
#applying knearest neighbors for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        knearest_neighbour(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        knearest_neighbour(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        knearest_neighbour(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        knearest_neighbour(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        knearest_neighbour(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13704   281]
#  [  917   601]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96     13985
#            1       0.68      0.40      0.50      1518
#
#     accuracy                           0.92     15503
#    macro avg       0.81      0.69      0.73     15503
# weighted avg       0.91      0.92      0.91     15503
#
# ROC_AUC_Score 0.6879113608925054
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4433   70]
#  [ 281  168]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      4503
#            1       0.71      0.37      0.49       449
#
#     accuracy                           0.93      4952
#    macro avg       0.82      0.68      0.73      4952
# weighted avg       0.92      0.93      0.92      4952
#
# ROC_AUC_Score 0.6793098092981319
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7830  190]
#  [ 505  308]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      8020
#            1       0.62      0.38      0.47       813
#
#     accuracy                           0.92      8833
#    macro avg       0.78      0.68      0.71      8833
# weighted avg       0.91      0.92      0.91      8833
#
# ROC_AUC_Score 0.6775765076852763
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3939   66]
#  [ 128  250]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      4005
#            1       0.79      0.66      0.72       378
#
#     accuracy                           0.96      4383
#    macro avg       0.88      0.82      0.85      4383
# weighted avg       0.95      0.96      0.95      4383
#
# ROC_AUC_Score 0.8224481303132989
# Vote_Prediction
#
# Confusion Matrix
#
# [[3651   66]
#  [ 266  382]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96      3717
#            1       0.85      0.59      0.70       648
#
#     accuracy                           0.92      4365
#    macro avg       0.89      0.79      0.83      4365
# weighted avg       0.92      0.92      0.92      4365
#
# ROC_AUC_Score 0.7858749588975578

# %%
#applying random forest for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        random_forest(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        random_forest(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        random_forest(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        random_forest(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        random_forest(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13662   323]
#  [  806   712]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96     13985
#            1       0.69      0.47      0.56      1518
#
#     accuracy                           0.93     15503
#    macro avg       0.82      0.72      0.76     15503
# weighted avg       0.92      0.93      0.92     15503
#
# ROC_AUC_Score 0.7229710168479969
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4404   99]
#  [ 246  203]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      4503
#            1       0.67      0.45      0.54       449
#
#     accuracy                           0.93      4952
#    macro avg       0.81      0.72      0.75      4952
# weighted avg       0.92      0.93      0.92      4952
#
# ROC_AUC_Score 0.7150652349064988
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7792  228]
#  [ 422  391]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      8020
#            1       0.63      0.48      0.55       813
#
#     accuracy                           0.93      8833
#    macro avg       0.79      0.73      0.75      8833
# weighted avg       0.92      0.93      0.92      8833
#
# ROC_AUC_Score 0.7262529408336478
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3947   58]
#  [  96  282]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      4005
#            1       0.83      0.75      0.79       378
#
#     accuracy                           0.96      4383
#    macro avg       0.90      0.87      0.88      4383
# weighted avg       0.96      0.96      0.96      4383
#
# ROC_AUC_Score 0.8657749242018905
# Vote_Prediction
#
# Confusion Matrix
#
# [[3632   85]
#  [ 228  420]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      3717
#            1       0.83      0.65      0.73       648
#
#     accuracy                           0.93      4365
#    macro avg       0.89      0.81      0.84      4365
# weighted avg       0.92      0.93      0.92      4365
#
# ROC_AUC_Score 0.8126401219621558

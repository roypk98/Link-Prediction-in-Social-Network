# %%
#imp libraries
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
# function for neural network
def neural_network(feat):
    
    X=feat.drop(['Link', 'C_Neighbour', 'P_Attachment',
       'Jaccard_Index', 'Adamic_Adar', 'Salton_Cosine',
       'Sorensen_Index', 'Promoted_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    neural=MLPClassifier()
    neural.fit(X_train,y_train)
    predictions=neural.predict(X_test)
    
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#function for knearest_neighbor
def knearest_neighbour(feat_temp):
    
    scaler=StandardScaler()
    scaler.fit(feat_temp.drop('Link',axis=1))
    scaled_feat=scaler.transform(feat_temp.drop('Link',axis=1))
    
    feat=pd.DataFrame(scaled_feat,columns=feat_temp.columns.drop('Link'))
    
    X=feat.drop(['C_Neighbour', 'P_Attachment', 'Jaccard_Index', 'Adamic_Adar', 'Salton_Cosine',
       'Sorensen_Index', 'Promoted_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat_temp['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    knn=KNeighborsClassifier(n_neighbors=6)
    knn.fit(X_train,y_train)
    predictions=knn.predict(X_test)
        
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#function for random_forest
def random_forest(feat):
    
    X=feat.drop(['Link', 'C_Neighbour', 'P_Attachment',
       'Jaccard_Index', 'Adamic_Adar', 'Salton_Cosine',
       'Sorensen_Index', 'Promoted_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    rfc=RandomForestClassifier()
    rfc.fit(X_train,y_train)
    predictions=rfc.predict(X_test)
    
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#applying neural network for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        neural_network(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        neural_network(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        neural_network(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        neural_network(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        neural_network(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13842   143]
#  [ 1069   449]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96     13985
#            1       0.76      0.30      0.43      1518
#
#     accuracy                           0.92     15503
#    macro avg       0.84      0.64      0.69     15503
# weighted avg       0.91      0.92      0.91     15503
#
# ROC_AUC_Score 0.6427793424443562
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4426   77]
#  [ 269  180]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      4503
#            1       0.70      0.40      0.51       449
#
#     accuracy                           0.93      4952
#    macro avg       0.82      0.69      0.74      4952
# weighted avg       0.92      0.93      0.92      4952
#
# ROC_AUC_Score 0.6918955786466533
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7929   91]
#  [ 457  356]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      8020
#            1       0.80      0.44      0.57       813
#
#     accuracy                           0.94      8833
#    macro avg       0.87      0.71      0.77      8833
# weighted avg       0.93      0.94      0.93      8833
#
# ROC_AUC_Score 0.7132688727136648
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3980   25]
#  [ 175  203]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      4005
#            1       0.89      0.54      0.67       378
#
#     accuracy                           0.95      4383
#    macro avg       0.92      0.77      0.82      4383
# weighted avg       0.95      0.95      0.95      4383
#
# ROC_AUC_Score 0.765397419891802
# Vote_Prediction
#
# Confusion Matrix
#
# [[3624   93]
#  [ 212  436]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96      3717
#            1       0.82      0.67      0.74       648
#
#     accuracy                           0.93      4365
#    macro avg       0.88      0.82      0.85      4365
# weighted avg       0.93      0.93      0.93      4365
#
# ROC_AUC_Score 0.8239096643051445

# %%
#applying knearest neighbors for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        knearest_neighbour(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        knearest_neighbour(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        knearest_neighbour(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        knearest_neighbour(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        knearest_neighbour(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13702   283]
#  [  902   616]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96     13985
#            1       0.69      0.41      0.51      1518
#
#     accuracy                           0.92     15503
#    macro avg       0.81      0.69      0.73     15503
# weighted avg       0.91      0.92      0.91     15503
#
# ROC_AUC_Score 0.69278056717083
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4415   88]
#  [ 276  173]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      4503
#            1       0.66      0.39      0.49       449
#
#     accuracy                           0.93      4952
#    macro avg       0.80      0.68      0.72      4952
# weighted avg       0.92      0.93      0.92      4952
#
# ROC_AUC_Score 0.6828790704736808
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7882  138]
#  [ 432  381]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      8020
#            1       0.73      0.47      0.57       813
#
#     accuracy                           0.94      8833
#    macro avg       0.84      0.73      0.77      8833
# weighted avg       0.93      0.94      0.93      8833
#
# ROC_AUC_Score 0.7257138519016113
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3957   48]
#  [ 112  266]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      4005
#            1       0.85      0.70      0.77       378
#
#     accuracy                           0.96      4383
#    macro avg       0.91      0.85      0.87      4383
# weighted avg       0.96      0.96      0.96      4383
#
# ROC_AUC_Score 0.845859342488556
# Vote_Prediction
#
# Confusion Matrix
#
# [[3644   73]
#  [ 229  419]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      3717
#            1       0.85      0.65      0.74       648
#
#     accuracy                           0.93      4365
#    macro avg       0.90      0.81      0.85      4365
# weighted avg       0.93      0.93      0.93      4365
#
# ROC_AUC_Score 0.8134827220279197

# %%
#applying random forest for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        random_forest(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        random_forest(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        random_forest(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        random_forest(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        random_forest(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13665   320]
#  [  774   744]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96     13985
#            1       0.70      0.49      0.58      1518
#
#     accuracy                           0.93     15503
#    macro avg       0.82      0.73      0.77     15503
# weighted avg       0.92      0.93      0.92     15503
#
# ROC_AUC_Score 0.7336184590774135
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4394  109]
#  [ 244  205]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      4503
#            1       0.65      0.46      0.54       449
#
#     accuracy                           0.93      4952
#    macro avg       0.80      0.72      0.75      4952
# weighted avg       0.92      0.93      0.92      4952
#
# ROC_AUC_Score 0.7161820355348352
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7844  176]
#  [ 371  442]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      8020
#            1       0.72      0.54      0.62       813
#
#     accuracy                           0.94      8833
#    macro avg       0.84      0.76      0.79      8833
# weighted avg       0.93      0.94      0.93      8833
#
# ROC_AUC_Score 0.7608601497486296
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3963   42]
#  [  77  301]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      4005
#            1       0.88      0.80      0.83       378
#
#     accuracy                           0.97      4383
#    macro avg       0.93      0.89      0.91      4383
# weighted avg       0.97      0.97      0.97      4383
#
# ROC_AUC_Score 0.8929047024552642
# Vote_Prediction
#
# Confusion Matrix
#
# [[3634   83]
#  [ 184  464]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      3717
#            1       0.85      0.72      0.78       648
#
#     accuracy                           0.94      4365
#    macro avg       0.90      0.85      0.87      4365
# weighted avg       0.94      0.94      0.94      4365
#
# ROC_AUC_Score 0.8468597734134458

# %%
#imp libraries
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
# function for neural network
def neural_network(feat):
    
    X=feat.drop(['Link', 'C_Neighbour', 'P_Attachment',
       'Jaccard_Index', 'Adamic_Adar', 'R_Allocation',
       'Sorensen_Index', 'Promoted_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    neural=MLPClassifier()
    neural.fit(X_train,y_train)
    predictions=neural.predict(X_test)
    
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#function for knearest_neighbor
def knearest_neighbour(feat_temp):
    
    scaler=StandardScaler()
    scaler.fit(feat_temp.drop('Link',axis=1))
    scaled_feat=scaler.transform(feat_temp.drop('Link',axis=1))
    
    feat=pd.DataFrame(scaled_feat,columns=feat_temp.columns.drop('Link'))
    
    X=feat.drop(['C_Neighbour', 'P_Attachment', 'Jaccard_Index', 'Adamic_Adar', 'R_Allocation',
       'Sorensen_Index', 'Promoted_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat_temp['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    knn=KNeighborsClassifier(n_neighbors=6)
    knn.fit(X_train,y_train)
    predictions=knn.predict(X_test)
        
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#function for random_forest
def random_forest(feat):
    
    X=feat.drop(['Link', 'C_Neighbour', 'P_Attachment',
       'Jaccard_Index', 'Adamic_Adar', 'R_Allocation',
       'Sorensen_Index', 'Promoted_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    rfc=RandomForestClassifier()
    rfc.fit(X_train,y_train)
    predictions=rfc.predict(X_test)
    
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#applying neural network for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        neural_network(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        neural_network(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        neural_network(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        neural_network(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        neural_network(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13693   292]
#  [  826   692]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96     13985
#            1       0.70      0.46      0.55      1518
#
#     accuracy                           0.93     15503
#    macro avg       0.82      0.72      0.76     15503
# weighted avg       0.92      0.93      0.92     15503
#
# ROC_AUC_Score 0.71749173191868
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4486   17]
#  [ 374   75]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      4503
#            1       0.82      0.17      0.28       449
#
#     accuracy                           0.92      4952
#    macro avg       0.87      0.58      0.62      4952
# weighted avg       0.91      0.92      0.90      4952
#
# ROC_AUC_Score 0.5816313004891073
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7957   63]
#  [ 618  195]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      8020
#            1       0.76      0.24      0.36       813
#
#     accuracy                           0.92      8833
#    macro avg       0.84      0.62      0.66      8833
# weighted avg       0.91      0.92      0.90      8833
#
# ROC_AUC_Score 0.6159985184639877
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3920   85]
#  [ 105  273]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      4005
#            1       0.76      0.72      0.74       378
#
#     accuracy                           0.96      4383
#    macro avg       0.87      0.85      0.86      4383
# weighted avg       0.96      0.96      0.96      4383
#
# ROC_AUC_Score 0.8504993757802747
# Vote_Prediction
#
# Confusion Matrix
#
# [[3648   69]
#  [ 270  378]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96      3717
#            1       0.85      0.58      0.69       648
#
#     accuracy                           0.92      4365
#    macro avg       0.89      0.78      0.82      4365
# weighted avg       0.92      0.92      0.92      4365
#
# ROC_AUC_Score 0.7823849878934626

# %%
#applying knearest neighbors for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        knearest_neighbour(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        knearest_neighbour(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        knearest_neighbour(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        knearest_neighbour(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        knearest_neighbour(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13683   302]
#  [  901   617]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96     13985
#            1       0.67      0.41      0.51      1518
#
#     accuracy                           0.92     15503
#    macro avg       0.80      0.69      0.73     15503
# weighted avg       0.91      0.92      0.91     15503
#
# ROC_AUC_Score 0.6924306486857978
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4424   79]
#  [ 293  156]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      4503
#            1       0.66      0.35      0.46       449
#
#     accuracy                           0.92      4952
#    macro avg       0.80      0.66      0.71      4952
# weighted avg       0.91      0.92      0.91      4952
#
# ROC_AUC_Score 0.6649474465674208
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7841  179]
#  [ 506  307]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      8020
#            1       0.63      0.38      0.47       813
#
#     accuracy                           0.92      8833
#    macro avg       0.79      0.68      0.72      8833
# weighted avg       0.91      0.92      0.91      8833
#
# ROC_AUC_Score 0.6776472870713744
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3938   67]
#  [ 105  273]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      4005
#            1       0.80      0.72      0.76       378
#
#     accuracy                           0.96      4383
#    macro avg       0.89      0.85      0.87      4383
# weighted avg       0.96      0.96      0.96      4383
#
# ROC_AUC_Score 0.8527465667915107
# Vote_Prediction
#
# Confusion Matrix
#
# [[3642   75]
#  [ 274  374]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      3717
#            1       0.83      0.58      0.68       648
#
#     accuracy                           0.92      4365
#    macro avg       0.88      0.78      0.82      4365
# weighted avg       0.92      0.92      0.91      4365
#
# ROC_AUC_Score 0.7784914656383584

# %%
#applying random forest for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        random_forest(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        random_forest(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        random_forest(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        random_forest(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        random_forest(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13627   358]
#  [  783   735]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96     13985
#            1       0.67      0.48      0.56      1518
#
#     accuracy                           0.93     15503
#    macro avg       0.81      0.73      0.76     15503
# weighted avg       0.92      0.93      0.92     15503
#
# ROC_AUC_Score 0.729295433701552
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4388  115]
#  [ 246  203]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      4503
#            1       0.64      0.45      0.53       449
#
#     accuracy                           0.93      4952
#    macro avg       0.79      0.71      0.74      4952
# weighted avg       0.92      0.93      0.92      4952
#
# ROC_AUC_Score 0.7132886415243093
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7805  215]
#  [ 411  402]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96      8020
#            1       0.65      0.49      0.56       813
#
#     accuracy                           0.93      8833
#    macro avg       0.80      0.73      0.76      8833
# weighted avg       0.92      0.93      0.92      8833
#
# ROC_AUC_Score 0.7338284822997856
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3943   62]
#  [  82  296]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      4005
#            1       0.83      0.78      0.80       378
#
#     accuracy                           0.97      4383
#    macro avg       0.90      0.88      0.89      4383
# weighted avg       0.97      0.97      0.97      4383
#
# ROC_AUC_Score 0.8837940669401343
# Vote_Prediction
#
# Confusion Matrix
#
# [[3642   75]
#  [ 223  425]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      3717
#            1       0.85      0.66      0.74       648
#
#     accuracy                           0.93      4365
#    macro avg       0.90      0.82      0.85      4365
# weighted avg       0.93      0.93      0.93      4365
#
# ROC_AUC_Score 0.8178433174902102

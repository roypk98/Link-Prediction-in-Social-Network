# %%
#imp libraries
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
# function for neural network
def neural_network(feat):
    
    X=feat.drop(['Link', 'C_Neighbour', 'P_Attachment',
       'Jaccard_Index', 'Adamic_Adar', 'R_Allocation', 'Salton_Cosine',
       'Sorensen_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    neural=MLPClassifier()
    neural.fit(X_train,y_train)
    predictions=neural.predict(X_test)
    
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#function for knearest_neighbor
def knearest_neighbour(feat_temp):
    
    scaler=StandardScaler()
    scaler.fit(feat_temp.drop('Link',axis=1))
    scaled_feat=scaler.transform(feat_temp.drop('Link',axis=1))
    
    feat=pd.DataFrame(scaled_feat,columns=feat_temp.columns.drop('Link'))
    
    X=feat.drop(['C_Neighbour', 'P_Attachment', 'Jaccard_Index', 'Adamic_Adar', 'R_Allocation', 'Salton_Cosine',
       'Sorensen_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat_temp['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    knn=KNeighborsClassifier(n_neighbors=6)
    knn.fit(X_train,y_train)
    predictions=knn.predict(X_test)
        
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#function for random_forest
def random_forest(feat):
    
    X=feat.drop(['Link', 'C_Neighbour', 'P_Attachment',
       'Jaccard_Index', 'Adamic_Adar', 'R_Allocation', 'Salton_Cosine',
       'Sorensen_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    rfc=RandomForestClassifier()
    rfc.fit(X_train,y_train)
    predictions=rfc.predict(X_test)
    
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#applying neural network for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        neural_network(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        neural_network(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        neural_network(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        neural_network(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        neural_network(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13908    77]
#  [ 1353   165]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     13985
#            1       0.68      0.11      0.19      1518
#
#     accuracy                           0.91     15503
#    macro avg       0.80      0.55      0.57     15503
# weighted avg       0.89      0.91      0.88     15503
#
# ROC_AUC_Score 0.5515948764981113
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4455   48]
#  [ 423   26]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      4503
#            1       0.35      0.06      0.10       449
#
#     accuracy                           0.90      4952
#    macro avg       0.63      0.52      0.52      4952
# weighted avg       0.86      0.90      0.87      4952
#
# ROC_AUC_Score 0.5236234492520948
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7988   32]
#  [ 760   53]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      8020
#            1       0.62      0.07      0.12       813
#
#     accuracy                           0.91      8833
#    macro avg       0.77      0.53      0.54      8833
# weighted avg       0.89      0.91      0.88      8833
#
# ROC_AUC_Score 0.5306003134844316
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3945   60]
#  [ 153  225]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      4005
#            1       0.79      0.60      0.68       378
#
#     accuracy                           0.95      4383
#    macro avg       0.88      0.79      0.83      4383
# weighted avg       0.95      0.95      0.95      4383
#
# ROC_AUC_Score 0.7901284109149278
# Vote_Prediction
#
# Confusion Matrix
#
# [[3643   74]
#  [ 313  335]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      3717
#            1       0.82      0.52      0.63       648
#
#     accuracy                           0.91      4365
#    macro avg       0.87      0.75      0.79      4365
# weighted avg       0.91      0.91      0.90      4365
#
# ROC_AUC_Score 0.7485333901294353

# %%
#applying knearest neighbors for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        knearest_neighbour(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        knearest_neighbour(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        knearest_neighbour(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        knearest_neighbour(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        knearest_neighbour(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13674   311]
#  [ 1097   421]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     13985
#            1       0.58      0.28      0.37      1518
#
#     accuracy                           0.91     15503
#    macro avg       0.75      0.63      0.66     15503
# weighted avg       0.89      0.91      0.89     15503
#
# ROC_AUC_Score 0.6275502455812105
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4411   92]
#  [ 371   78]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      4503
#            1       0.46      0.17      0.25       449
#
#     accuracy                           0.91      4952
#    macro avg       0.69      0.58      0.60      4952
# weighted avg       0.88      0.91      0.89      4952
#
# ROC_AUC_Score 0.5766442762484005
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7839  181]
#  [ 576  237]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      8020
#            1       0.57      0.29      0.39       813
#
#     accuracy                           0.91      8833
#    macro avg       0.75      0.63      0.67      8833
# weighted avg       0.90      0.91      0.90      8833
#
# ROC_AUC_Score 0.6344721682877678
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3930   75]
#  [ 121  257]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      4005
#            1       0.77      0.68      0.72       378
#
#     accuracy                           0.96      4383
#    macro avg       0.87      0.83      0.85      4383
# weighted avg       0.95      0.96      0.95      4383
#
# ROC_AUC_Score 0.8305837940669402
# Vote_Prediction
#
# Confusion Matrix
#
# [[3638   79]
#  [ 298  350]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      3717
#            1       0.82      0.54      0.65       648
#
#     accuracy                           0.91      4365
#    macro avg       0.87      0.76      0.80      4365
# weighted avg       0.91      0.91      0.91      4365
#
# ROC_AUC_Score 0.7594348787851612

# %%
#applying random forest for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        random_forest(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        random_forest(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        random_forest(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        random_forest(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        random_forest(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13591   394]
#  [  896   622]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95     13985
#            1       0.61      0.41      0.49      1518
#
#     accuracy                           0.92     15503
#    macro avg       0.78      0.69      0.72     15503
# weighted avg       0.91      0.92      0.91     15503
#
# ROC_AUC_Score 0.6907883140368257
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4402  101]
#  [ 299  150]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96      4503
#            1       0.60      0.33      0.43       449
#
#     accuracy                           0.92      4952
#    macro avg       0.77      0.66      0.69      4952
# weighted avg       0.91      0.92      0.91      4952
#
# ROC_AUC_Score 0.6558231161902953
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7806  214]
#  [ 465  348]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96      8020
#            1       0.62      0.43      0.51       813
#
#     accuracy                           0.92      8833
#    macro avg       0.78      0.70      0.73      8833
# weighted avg       0.91      0.92      0.92      8833
#
# ROC_AUC_Score 0.7006804943361155
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3938   67]
#  [  75  303]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      4005
#            1       0.82      0.80      0.81       378
#
#     accuracy                           0.97      4383
#    macro avg       0.90      0.89      0.90      4383
# weighted avg       0.97      0.97      0.97      4383
#
# ROC_AUC_Score 0.8924291064740503
# Vote_Prediction
#
# Confusion Matrix
#
# [[3621   96]
#  [ 241  407]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96      3717
#            1       0.81      0.63      0.71       648
#
#     accuracy                           0.92      4365
#    macro avg       0.87      0.80      0.83      4365
# weighted avg       0.92      0.92      0.92      4365
#
# ROC_AUC_Score 0.8011295698442591

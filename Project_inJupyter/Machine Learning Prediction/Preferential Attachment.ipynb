# %%
#imp libraries
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
# function for neural network
def neural_network(feat):
    
    X=feat.drop(['Link', 'C_Neighbour',
       'Jaccard_Index', 'Adamic_Adar', 'R_Allocation', 'Salton_Cosine',
       'Sorensen_Index', 'Promoted_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    neural=MLPClassifier()
    neural.fit(X_train,y_train)
    predictions=neural.predict(X_test)
    
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#function for knearest_neighbor
def knearest_neighbour(feat_temp):
    
    scaler=StandardScaler()
    scaler.fit(feat_temp.drop('Link',axis=1))
    scaled_feat=scaler.transform(feat_temp.drop('Link',axis=1))
    
    feat=pd.DataFrame(scaled_feat,columns=feat_temp.columns.drop('Link'))
    
    X=feat.drop(['C_Neighbour', 'Jaccard_Index', 'Adamic_Adar', 'R_Allocation', 'Salton_Cosine',
       'Sorensen_Index', 'Promoted_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat_temp['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    knn=KNeighborsClassifier(n_neighbors=6)
    knn.fit(X_train,y_train)
    predictions=knn.predict(X_test)
        
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#function for random_forest
def random_forest(feat):
    
    X=feat.drop(['Link', 'C_Neighbour',
       'Jaccard_Index', 'Adamic_Adar', 'R_Allocation', 'Salton_Cosine',
       'Sorensen_Index', 'Promoted_Index', 'Depressed_Index', 'LHN_Index'],axis=1)
    y=feat['Link']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    
    rfc=RandomForestClassifier()
    rfc.fit(X_train,y_train)
    predictions=rfc.predict(X_test)
    
    print('Confusion Matrix\n')
    print(confusion_matrix(y_test,predictions))
    print('\nClassification Report\n')
    print(classification_report(y_test,predictions))
    
    false_positive_rate, true_positive_rate, threshold = roc_curve(y_test, predictions)
    print('ROC_AUC_Score', roc_auc_score(y_test, predictions))
    
    plt.subplots(1, figsize=(5,5))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate, true_positive_rate)
    plt.plot([0, 1], ls="--")
    plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
#applying neural network for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        neural_network(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        neural_network(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        neural_network(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        neural_network(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        neural_network(v_feat)
# Out:
# FB_Prediction
# C:\Users\Hp\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Confusion Matrix
#
# [[13964    21]
#  [ 1478    40]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95     13985
#            1       0.66      0.03      0.05      1518
#
#     accuracy                           0.90     15503
#    macro avg       0.78      0.51      0.50     15503
# weighted avg       0.88      0.90      0.86     15503
#
# ROC_AUC_Score 0.5124244261332135
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[3740  763]
#  [ 188  261]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.83      0.89      4503
#            1       0.25      0.58      0.35       449
#
#     accuracy                           0.81      4952
#    macro avg       0.60      0.71      0.62      4952
# weighted avg       0.89      0.81      0.84      4952
#
# ROC_AUC_Score 0.7059245828195704
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7534  486]
#  [ 578  235]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93      8020
#            1       0.33      0.29      0.31       813
#
#     accuracy                           0.88      8833
#    macro avg       0.63      0.61      0.62      8833
# weighted avg       0.87      0.88      0.88      8833
#
# ROC_AUC_Score 0.6142271933941286
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3930   75]
#  [ 314   64]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      4005
#            1       0.46      0.17      0.25       378
#
#     accuracy                           0.91      4383
#    macro avg       0.69      0.58      0.60      4383
# weighted avg       0.89      0.91      0.89      4383
#
# ROC_AUC_Score 0.5752927887759348
# Vote_Prediction
#
# Confusion Matrix
#
# [[3451  266]
#  [ 329  319]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92      3717
#            1       0.55      0.49      0.52       648
#
#     accuracy                           0.86      4365
#    macro avg       0.73      0.71      0.72      4365
# weighted avg       0.86      0.86      0.86      4365
#
# ROC_AUC_Score 0.7103604310525214

# %%
#applying knearest neighbors for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        knearest_neighbour(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        knearest_neighbour(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        knearest_neighbour(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        knearest_neighbour(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        knearest_neighbour(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13882   103]
#  [ 1435    83]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     13985
#            1       0.45      0.05      0.10      1518
#
#     accuracy                           0.90     15503
#    macro avg       0.68      0.52      0.52     15503
# weighted avg       0.86      0.90      0.86     15503
#
# ROC_AUC_Score 0.5236560864430787
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4455   48]
#  [ 405   44]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      4503
#            1       0.48      0.10      0.16       449
#
#     accuracy                           0.91      4952
#    macro avg       0.70      0.54      0.56      4952
# weighted avg       0.88      0.91      0.88      4952
#
# ROC_AUC_Score 0.5436679926819389
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7939   81]
#  [ 768   45]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8020
#            1       0.36      0.06      0.10       813
#
#     accuracy                           0.90      8833
#    macro avg       0.63      0.52      0.52      8833
# weighted avg       0.86      0.90      0.87      8833
#
# ROC_AUC_Score 0.5226254014410467
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3965   40]
#  [ 317   61]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96      4005
#            1       0.60      0.16      0.25       378
#
#     accuracy                           0.92      4383
#    macro avg       0.76      0.58      0.61      4383
# weighted avg       0.90      0.92      0.90      4383
#
# ROC_AUC_Score 0.5756940728850841
# Vote_Prediction
#
# Confusion Matrix
#
# [[3628   89]
#  [ 389  259]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94      3717
#            1       0.74      0.40      0.52       648
#
#     accuracy                           0.89      4365
#    macro avg       0.82      0.69      0.73      4365
# weighted avg       0.88      0.89      0.88      4365
#
# ROC_AUC_Score 0.687873658565749

# %%
#applying random forest for all 5 dataset
for i in range(5):
    if(i==0):
        f_feat=pd.read_csv('FB/FB_Features.csv')
        print('FB_Prediction\n')
        random_forest(f_feat)
    elif(i==1):
        ff_feat=pd.read_csv('FB_Food/FBF_Features.csv')
        print('FB_Food_Prediction\n')
        random_forest(ff_feat)
    elif(i==2):
        fs_feat=pd.read_csv('FB_Sport/FBS_Features.csv')
        print('FB_Sport_Prediction\n')
        random_forest(fs_feat)
    elif(i==3):
        h_feat=pd.read_csv('Ham/Ham_Features.csv')
        print('Hamsterster_Prediction\n')
        random_forest(h_feat)
    else:
        v_feat=pd.read_csv('Vote/Vote_Features.csv')
        print('Vote_Prediction\n')
        random_forest(v_feat)
# Out:
# FB_Prediction
#
# Confusion Matrix
#
# [[13852   133]
#  [ 1386   132]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     13985
#            1       0.50      0.09      0.15      1518
#
#     accuracy                           0.90     15503
#    macro avg       0.70      0.54      0.55     15503
# weighted avg       0.87      0.90      0.87     15503
#
# ROC_AUC_Score 0.5387231661251962
# FB_Food_Prediction
#
# Confusion Matrix
#
# [[4426   77]
#  [ 378   71]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      4503
#            1       0.48      0.16      0.24       449
#
#     accuracy                           0.91      4952
#    macro avg       0.70      0.57      0.59      4952
# weighted avg       0.88      0.91      0.89      4952
#
# ROC_AUC_Score 0.5705147323214863
# FB_Sport_Prediction
#
# Confusion Matrix
#
# [[7924   96]
#  [ 740   73]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95      8020
#            1       0.43      0.09      0.15       813
#
#     accuracy                           0.91      8833
#    macro avg       0.67      0.54      0.55      8833
# weighted avg       0.87      0.91      0.88      8833
#
# ROC_AUC_Score 0.5389104115480057
# Hamsterster_Prediction
#
# Confusion Matrix
#
# [[3962   43]
#  [ 261  117]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      4005
#            1       0.73      0.31      0.43       378
#
#     accuracy                           0.93      4383
#    macro avg       0.83      0.65      0.70      4383
# weighted avg       0.92      0.93      0.92      4383
#
# ROC_AUC_Score 0.6493936151239522
# Vote_Prediction
#
# Confusion Matrix
#
# [[3626   91]
#  [ 340  308]]
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      3717
#            1       0.77      0.48      0.59       648
#
#     accuracy                           0.90      4365
#    macro avg       0.84      0.73      0.77      4365
# weighted avg       0.89      0.90      0.89      4365
#
# ROC_AUC_Score 0.7254132663737183
